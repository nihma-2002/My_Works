# %%
#Q1

MS=c(3.63,4.2,3.33,4.54,2.89,4.87,4.9,5.29,6.18,7.2,7.25,6.09,6.8,8.65,8.43,8.29,7.18,7.9,8.45,8.23)
p=c(0.97,0.95,0.99,0.91,0.98,0.9,0.89,0.86,0.85,0.82,0.79,0.83,0.81,0.77,0.76,0.8,0.83,0.79,0.76,0.78)
data=data.frame(MS,p)
data
model=lm(MS~p,data=data)
model
names(model)
Residuals=model$residuals
Residuals
par(mfrow=c(2,2))
plot(model)
plot(Residuals)

install.packages("carData")
install.packages("car")
library(carData)
library(car)
ncvTest(model)

durbinWatsonTest(model)

#Q2

X1=c(14.57,24.02,20.42,19.74,49.2,44.92,55.48,59.28,94.39,148.02)
X2=c(2253,2048,3940,6505,5723,11520,5779,5969,8461,20406)
X3=c(482.92,1339.75,620.25,568.33,1497.6,1365.8,1687,1639.92,2872.33,3655.1)
X4=c(18,9.5,12.8,36.7,35.7,24,43.3,46.7,78.7,180.5)
X5=c(4.45,6.92,4.28,3.9,5.5,4.6,5.62,5.15,6.18,6.15)
Y=c(554.52,676.82,1028.15,1603.62,1611.37,1613.27,1854.17,2160.55,2305.58,3503.9)
data=data.frame(X1,X2,X3,X4,X5,Y)
data
model1=lm(Y~X1+X2+X3+X4+X5,data=data)
model1
names(model1)
summary(model1)

data1=data.frame(X1,X2,X3,X4,X5)
data1
cor(data1)

Residual=model1$residuals
Residual
par(mfrow=c(2,2))
plot(model1)
plot(Residual)
ncvTest(model1)

vif(model1)

#Q3
install.packages("psych")
library(psych)
data=cars
data
summary(cars)
describe(cars)
b=boxplot(cars)
b$names
b$out

model2=lm(dist~speed,data=data)
model2

cor(data)


summary(model2)

par(mfrow=c(2,2))
plot(model2)
residuals=model2$residuals
residuals
mean(residuals)
var(residuals)

durbinWatsonTest(model12)
# Out:
#    MS   p
# 1  3.63 0.97
# 2  4.20 0.95
# 3  3.33 0.99
# 4  4.54 0.91
# 5  2.89 0.98
# 6  4.87 0.90
# 7  4.90 0.89
# 8  5.29 0.86
# 9  6.18 0.85
# 10 7.20 0.82
# 11 7.25 0.79
# 12 6.09 0.83
# 13 6.80 0.81
# 14 8.65 0.77
# 15 8.43 0.76
# 16 8.29 0.80
# 17 7.18 0.83
# 18 7.90 0.79
# 19 8.45 0.76
# 20 8.23 0.78
# Call:
# lm(formula = MS ~ p, data = data)
#
# Coefficients:
# (Intercept)            p
#       26.91       -24.29
#  [1] "coefficients"  "residuals"     "effects"       "rank"
#  [5] "fitted.values" "assign"        "qr"            "df.residual"
#  [9] "xlevels"       "call"          "terms"         "model"
#             1             2             3             4             5
#  0.2811931818  0.3653977273  0.4669886364 -0.2661931818 -0.2159090909
#             6             7             8             9            10
# -0.1790909091 -0.3919886364 -0.7306818182 -0.0835795455  0.2077272727
#            11            12            13            14            15
# ...
