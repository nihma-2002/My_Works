# %%
#Q3

t=c(1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983)
yt=c(66.6,84.6,88.6,78,96.8,105.2,93.2,111.6,88.3,117,115.2)
plot(t,yt,type='l')
model=lm(yt~t)
model
A=median(t)
yt_cap=model$fitted.values
yt_cap
#yt_cap=predict(model)
#yt_cap
eliminating_trend=yt-yt_cap
eliminating_trend

#Q4

t=c(1911,1921,1931,1941,1951,1961,1971,1981)
yt=c(25,25.1,27.9,31.9,36.1,43.9,54.7,60.8)
plot(t,yt,type='l')
model=lm(yt~t)
model
A=median(t)
yt_cap=model$fitted.values
yt_cap
eliminating_trend=yt-yt_cap
eliminating_trend
# Out:
# Call:
# lm(formula = yt ~ t)
#
# Coefficients:
# (Intercept)            t
#   -7732.476        3.957
#         1         2         3         4         5         6         7         8
#  75.22273  79.18000  83.13727  87.09455  91.05182  95.00909  98.96636 102.92364
#         9        10        11
# 106.88091 110.83818 114.79545
#           1           2           3           4           5           6
#  -8.6227273   5.4200000   5.4627273  -9.0945455   5.7481818  10.1909091
#           7           8           9          10          11
#  -5.7663636   8.6763636 -18.5809091   6.1618182   0.4045455
# plot without title
# Call:
# lm(formula = yt ~ t)
#
# Coefficients:
# (Intercept)            t
#  -1006.1783       0.5367
#        1        2        3        4        5        6        7        8
# 19.39167 24.75833 30.12500 35.49167 40.85833 46.22500 51.59167 56.95833
#          1          2          3          4          5          6          7
# ...
